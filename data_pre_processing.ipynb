# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data Collection

# %%
sales_2017 = pd.read_csv("Sales Transactions-2017.csv")

# %%
sales_2017.head(5)
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %%
sales_2018 = pd.read_csv("Sales Transactions-2018.csv")

# %%
sales_2018.head(5)
# Out:
#        Date  Voucher Party            Product       Qty Rate     Gross Disc  \
# 0  1/4/2018  Sal:146  TP13  SILVER POUCH 9*12        50   85  4,250.00  NaN
# 1  1/4/2018  Sal:146  TP13             RUBBER         5  290  1,450.00  NaN
# 2  1/4/2018  Sal:146  TP13   DURGA 10*12 Blue  1,600.00  5.5  8,800.00  NaN
# 3  1/4/2018  Sal:146  TP13   DURGA 13*16 BLUE       400   11  4,400.00  NaN
# 4  1/4/2018  Sal:146  TP13    10*12 SARAS-NAT       600  8.1  4,860.00  NaN
#
#   Voucher Amount
# 0      66,724.00
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
sales_2019 = pd.read_csv("Sales Transactions-2019.csv")

# %%
sales_2019.head(5)
# Out:
#        Date  Voucher            Party         Product  Qty      Rate  \
# 0  1/4/2019  Sal:687  BALAJI PLASTICS   DONA-VAI-9100    1  1,730.00
# 1  1/4/2019  Sal:687  BALAJI PLASTICS  SMART BOUL(48)    1  1,730.00
# 2  1/4/2019  Sal:688  BALAJI PLASTICS      Vishnu Ice  110      18.5
# 3                                28/3                    0         0
# 4  1/4/2019  Sal:689  BALAJI PLASTICS     100LEAF -SP    3       585
#
#       Gross Disc Voucher Amount
# 0  1,730.00  NaN       3,460.00
# 1  1,730.00  NaN            NaN
# 2  2,035.00  NaN       2,035.00
# 3
# 4  1,755.00  NaN       1,755.00

# %%
all_sales_data=pd.concat([sales_2017,sales_2018,sales_2019])

# %%
all_sales_data.head(5)
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %% [markdown]
# # Data Cleaning

# %%
all_sales_data.shape
# Out:
# (111206, 9)

# %%
all_sales_data.describe()
# Out:
#          Date Voucher   Party Product    Qty   Rate  Gross  Disc  \
# count   98615   98649  111166   98615  98649  98648  98648  5597
# unique    836   10044    1994     867    546   1109   2548   371
# top                      TP13            100
# freq     3053    3053   13056    3053  12528   3051   3053  3053
#
#        Voucher Amount
# count           27560
# unique           7149
# top
# freq             3053

# %%
all_sales_data.columns
# Out:
# Index(['Date', 'Voucher', 'Party', 'Product', 'Qty', 'Rate', 'Gross', 'Disc',
#        'Voucher Amount'],
#       dtype='object')

# %%
all_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111206 entries, 0 to 19175
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date            98615 non-null   object
#  1   Voucher         98649 non-null   object
#  2   Party           111166 non-null  object
#  3   Product         98615 non-null   object
#  4   Qty             98649 non-null   object
#  5   Rate            98648 non-null   object
#  6   Gross           98648 non-null   object
#  7   Disc            5597 non-null    object
#  8   Voucher Amount  27560 non-null   object
# dtypes: object(9)
# memory usage: 8.5+ MB

# %%
all_sales_data.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
all_sales_data.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
all_sales_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
all_sales_data=all_sales_data.drop(labels=['Gross','Disc','Voucher Amount'],axis=1)

# %%
all_sales_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate
# 0                 2      1,690.00
# 1                 6      1,620.00
# 2               500            23
# ...

# %%
all_sales_data.dropna(inplace=True)

# %%
all_sales_data
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 19167  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# ...

# %%
all_sales_data.drop_duplicates(inplace=True)

# %%
all_sales_data
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 19167  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# ...

# %%
all_sales_data.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# dtype: int64

# %%
all_sales_data.dtypes
# Out:
# Date       object
# Voucher    object
# Party      object
# Product    object
# Qty        object
# Rate       object
# dtype: object

# %%
all_sales_data["Rate"].unique()
# Out:
# array(['1,690.00', '1,620.00', '23', ..., '15.58', '22,600.00',
#        '14,069.70'], dtype=object)

# %%
all_sales_data["Rate"]=all_sales_data["Rate"].replace(",","",regex=True)

# %%
all_sales_data
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 19167  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#           Rate
# 0      1690.00
# 1      1620.00
# 2           23
# ...

# %%
all_sales_data["Rate"].dtypes
# Out:
# dtype('O')

# %%
all_sales_data["Rate"]=all_sales_data["Rate"].replace(" ","",regex=True)

# %%
all_sales_data["Rate"]=pd.to_numeric(all_sales_data["Rate"])

# %%
all_sales_data
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 19167  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# ...

# %%
all_sales_data["Voucher"].unique()
# Out:
# array(['Sal:1', 'Sal:2', 'Sal:898', ..., 'Sal:8727', 'Sal:9102',
#        'Sal:9193'], dtype=object)

# %%
all_sales_data["Voucher"]=pd.to_numeric(all_sales_data["Voucher"],errors="coerce")

# %%
all_sales_data["Voucher"].fillna(0,inplace=True)

# %%
all_sales_data["Voucher"]=all_sales_data["Voucher"].astype(int)

# %%
all_sales_data["Voucher"].unique()
# Out:
# array([0])

# %%
all_sales_data
# Out:
#              Date  Voucher               Party              Product  Qty  \
# 0        1/4/2017        0    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017        0    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017        0  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017        0  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017        0  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...      ...                 ...                  ...  ...
# 19167  10/10/2019        0           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019        0           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019        0           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019        0           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019        0           K.SRIHARI       13*16 WHITE RK  400
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# ...

# %%
all_sales_data["Qty"].unique()
# Out:
# array(['2', '6', '500', '5', '1', '100', ' ', '150', '10', '200', '3',
#        '20', '50', '30', '1,000.00', '25', '2,000.00', '35', '3,000.00',
#        '210', '300', '400', '11', '556', '6,000.00', '40', '9', '80',
#        '375', '24', '600', '15', '190', '14', '140', '350', '130',
#        '1,800.00', '1,600.00', '800', '939', '230', '700', '70', '27',
#        '72', '250', '450', '110', '8', '120', '4', '440', '650', '60',
#        '278', '1,500.00', '240', '312', '360', '1,440.00', '270', '25.85',
#        '900', '220', '160', '12', '630', '16', '313', '1,400.00', '90',
#        '26', '550', '23', '18', '7', '38', '32', '1,100.00', '125', '750',
#        '94', '1,050.00', '2,600.00', '75', '22.6', '480', '4,000.00',
#        '36', '180', '45', '5,000.00', '22.3', '26.8', '25.2', '420', '17',
#        '13', '12,000.00', '1,200.00', '216', '112', '7,000.00', '84',
#        '105', '330', '840', '62', '26.5', '22.5', '4,500.00', '24.5',
# ...

# %%
all_sales_data["Qty"]=all_sales_data["Qty"].replace(" ","",regex=True)

# %%
all_sales_data["Qty"]=pd.to_numeric(all_sales_data["Qty"], errors="coerce")

# %%
all_sales_data["Qty"].fillna(0, inplace=True)

# %%
all_sales_data["Qty"] = all_sales_data["Qty"].astype("int64")

# %%
all_sales_data["Qty"].round()
# Out:
# 0          2
# 1          6
# 2        500
# 3          6
# 4          5
#         ...
# 19167    140
# 19168    600
# 19169    320
# 19170    800
# 19171    400
# Name: Qty, Length: 96356, dtype: int64

# %%
all_sales_data["Qty"]=all_sales_data["Qty"].replace(".0","",regex=True)

# %%
all_sales_data
# Out:
#              Date  Voucher               Party              Product  Qty  \
# 0        1/4/2017        0    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017        0    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017        0  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017        0  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017        0  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...      ...                 ...                  ...  ...
# 19167  10/10/2019        0           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019        0           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019        0           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019        0           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019        0           K.SRIHARI       13*16 WHITE RK  400
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# ...

# %%
all_sales_data.dtypes
# Out:
# Date        object
# Voucher      int32
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %%
all_sales_data["Date"].unique()
# Out:
# array(['1/4/2017', ' ', '2/4/2017', '3/4/2017', '4/4/2017', '5/4/2017',
#        '6/4/2017', '7/4/2017', '8/4/2017', '9/4/2017', '10/4/2017',
#        '11/4/2017', '12/4/2017', '13/04/2017', '14/04/2017', '15/04/2017',
#        '17/04/2017', '18/04/2017', '19/04/2017', '20/04/2017',
#        '21/04/2017', '22/04/2017', '24/04/2017', '25/04/2017',
#        '26/04/2017', '27/04/2017', '28/04/2017', '29/04/2017',
#        '30/04/2017', '1/5/2017', '2/5/2017', '3/5/2017', '4/5/2017',
#        '5/5/2017', '6/5/2017', '8/5/2017', '9/5/2017', '10/5/2017',
#        '11/5/2017', '12/5/2017', '13/05/2017', '15/05/2017', '16/05/2017',
#        '17/05/2017', '18/05/2017', '19/05/2017', '20/05/2017',
#        '22/05/2017', '23/05/2017', '24/05/2017', '25/05/2017',
#        '26/05/2017', '27/05/2017', '29/05/2017', '30/05/2017',
#        '31/05/2017', '1/6/2017', '2/6/2017', '3/6/2017', '5/6/2017',
#        '6/6/2017', '7/6/2017', '8/6/2017', '9/6/2017', '10/6/2017',
# ...

# %%
all_sales_data["Date"]= all_sales_data["Date"].replace(" ","")
